# %% [markdown]
# ## datos de glottolog

# %%
import pandas as pd

# %%
## miramos languoids

languoid = pd.read_csv('Languages.csv',sep=',')

# %%
languoid
# Out:
#             ID              Name      Macroarea   Latitude   Longitude  \
# 0     guri1248           Guriaso      Papunesia  -3.571800  141.597000
# 1     pawa1255            Pawaia      Papunesia  -6.880210  145.081000
# 2     guam1236             Guamo  South America   8.235103  -67.401875
# 3     dama1272             Damal      Papunesia  -4.173450  137.496000
# 4     puqu1242           Puquina  South America -15.899200  -69.961100
# ...        ...               ...            ...        ...         ...
# 8113  guan1268  Guana (Paraguay)  South America -21.980300  -58.065400
# 8114  sana1298          Sanapaná  South America -22.490000  -58.380000
# 8115  anga1316           Angaité  South America -22.850000  -58.450000
# 8116  gily1242        Amur Nivkh        Eurasia  52.590000  140.681000
# 8117  sakh1247    Sakhalin Nivkh        Eurasia  51.781400  143.162800
#
#      Glottocode ISO639P3code Family_Glottocode    Family_Name    Status  \
# ...

# %%
languoid.columns
# Out:
# Index(['ID', 'Name', 'Macroarea', 'Latitude', 'Longitude', 'Glottocode',
#        'ISO639P3code', 'Family_Glottocode', 'Family_Name', 'Status',
#        'Parent_Glottocode'],
#       dtype='object')

# %%
languoid_SA = languoid[languoid['Macroarea']=='South America']

# %%
languoid_SA
# Out:
#             ID              Name      Macroarea   Latitude  Longitude  \
# 2     guam1236             Guamo  South America   8.235103 -67.401875
# 4     puqu1242           Puquina  South America -15.899200 -69.961100
# 6     vile1241            Vilela  South America -27.406300 -58.966100
# 8     arut1244           Arutani  South America   4.067359 -62.867612
# 10    movi1243            Movima  South America -13.811500 -65.634800
# ...        ...               ...            ...        ...        ...
# 8111  sout2989   Southern Lengua  South America -23.427556 -57.945626
# 8112  toba1268       Toba-Maskoy  South America -21.547400 -58.015800
# 8113  guan1268  Guana (Paraguay)  South America -21.980300 -58.065400
# 8114  sana1298          Sanapaná  South America -22.490000 -58.380000
# 8115  anga1316           Angaité  South America -22.850000 -58.450000
#
#      Glottocode ISO639P3code Family_Glottocode    Family_Name          Status  \
# ...

# %%
## diccionario lengua:family

lengua_family_SA = dict(zip(languoid_SA['Name'],languoid_SA['Family_Name']))

# %%
lengua_family_SA.keys()
# Out:
# dict_keys(['Guamo', 'Puquina', 'Vilela', 'Arutani', 'Movima', 'Muniche', 'Yurumanguí', 'Cayubaba', 'Yámana', 'Kunza', 'Lule', 'Itonama', 'Máku', 'Tuxá', 'Warao', 'Mure', 'Cofán', 'Irántxe-Münkü', 'Pankararú', 'Puinave', 'Betoi-Jirara', 'Atacame', 'Camsá', 'Andoque', 'Pirahã', 'Mochica', 'Leco', 'Oti', 'Sechuran', 'Lomeriano-Ignaciano Chiquitano', 'Xukurú', 'Pumé', 'Taushiro', 'Urarina', 'Tinigua', 'Aikanã', 'Candoshi-Shapra', 'Kanoê', 'Timote-Cuica', 'Migueleño Chiquitano', 'Waorani', 'Ramanos', 'Omurano', 'Taruma', 'Payagua', 'Culli', 'Jirajaran', 'Puelche', 'Mosetén-Chimané', 'Fulniô', 'Tallán', 'Kariri', 'Kwaza', 'Chono', 'Sapé', 'Yuracaré', 'Guató', 'Matanawí', 'Aewa', 'Mato Grosso Arára', 'Andaqui', 'Trumai', 'Páez', 'Canichana', 'Guachi', 'Bora', 'Muinane', 'Uru', 'Chipaya', 'Callawalla', 'Media Lengua', 'Caribbean Javanese', 'Karajá', 'Rikbaktsa', 'Ofayé', 'Gueren', 'Krenak', 'Geico', 'Panará', 'Suyá', 'Apinayé', 'Kayapó', 'Northeastern Timbira', 'Pará-Maranhão Gavião', 'Canel
# ...

# %%
lengua_family_SA['Southern Aymara']
# Out:
# 'Aymaran'
